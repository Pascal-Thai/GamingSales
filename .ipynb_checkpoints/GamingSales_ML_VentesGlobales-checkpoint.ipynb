# %%
# Importation des packaques et du dataset
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re
from sklearn import preprocessing
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LinearRegression, Ridge, Lasso, LogisticRegression,ElasticNet
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import mean_absolute_error
from sklearn.ensemble import GradientBoostingRegressor,RandomForestClassifier

import warnings
warnings.filterwarnings(action='ignore')

# !pip install category_encoders
import category_encoders as ce
ohe = ce.OneHotEncoder()

# Importation du fichier de scraping
df = pd.read_csv('vgsales.csv',index_col=False)

# Retrait des variables inutiles
df.drop(['Rank','Name','gamename','serie','NA_Sales','EU_Sales','JP_Sales','Other_Sales','metaNoteQ','samename','developper'],axis=1,inplace=True)
# Out:
# Requirement already satisfied: category_encoders in /opt/anaconda3/lib/python3.8/site-packages (2.3.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in /opt/anaconda3/lib/python3.8/site-packages (from category_encoders) (0.24.1)
# Requirement already satisfied: patsy>=0.5.1 in /opt/anaconda3/lib/python3.8/site-packages (from category_encoders) (0.5.1)
# Requirement already satisfied: scipy>=1.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from category_encoders) (1.6.2)
# Requirement already satisfied: pandas>=0.21.1 in /opt/anaconda3/lib/python3.8/site-packages (from category_encoders) (1.2.4)
# Requirement already satisfied: statsmodels>=0.9.0 in /opt/anaconda3/lib/python3.8/site-packages (from category_encoders) (0.12.2)
# Requirement already satisfied: numpy>=1.14.0 in /opt/anaconda3/lib/python3.8/site-packages (from category_encoders) (1.20.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.21.1->category_encoders) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.21.1->category_encoders) (2021.1)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.8/site-packages (from patsy>=0.5.1->category_encoders) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /opt/anaconda3/lib/python3.8/site-packages (from scikit-learn>=0.20.0->category_encoders) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from scikit-learn>=0.20.0->category_encoders) (2.1.0)

# %%
# Recherche des outliers
#plt.scatter(df.index,df['Global_Sales']);

plt.subplot(1,2,1)
plt.boxplot(df['Global_Sales']);
plt.ylim([0,80]);

plt.subplot(1,2,2)
plt.boxplot(df['Global_Sales']);
plt.ylim([0,20]);

plt.title("Recherche des outliers")

# Retrait des outliers
#df = df[df['Global_Sales']<20]

# Recherche des données manquantes
df.isnull().sum()

# Remplacement des années manquantes par 0 (autres)
df[['Year','metaNote','metaNbVote','userNote','userNbVote']] = df[['Year','metaNote','metaNbVote','userNote','userNbVote']].fillna(0)

# Remplacement des Publishers manquants par unknown
df['Publisher'] = df['Publisher'].fillna('unknown')

# Traitement des données catégorielles
df2 = ohe.fit_transform(df)

# %%
df2.info(20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11523 entries, 17 to 11539
# Data columns (total 2241 columns):
#  #     Column           Dtype
# ---    ------           -----
#  0     Platform_1       int64
#  1     Platform_2       int64
#  2     Platform_3       int64
#  3     Platform_4       int64
#  4     Platform_5       int64
#  5     Platform_6       int64
#  6     Platform_7       int64
#  7     Platform_8       int64
#  8     Platform_9       int64
#  9     Platform_10      int64
#  10    Platform_11      int64
#  11    Platform_12      int64
#  12    Platform_13      int64
#  13    Platform_14      int64
#  14    Platform_15      int64
#  15    Platform_16      int64
#  16    Platform_17      int64
#  17    Platform_18      int64
#  18    Platform_19      int64
#  19    Platform_20      int64
#  20    Platform_21      int64
#  21    Platform_22      int64
#  22    Platform_23      int64
#  23    Platform_24      int64
#  24    Platform_25      int64
#  25    Platform_26      int64
#  26    Platform_27      int64
#  27    Platform_28      int64
#  28    Platform_29      int64
#  29    Year             float64
#  30    Genre_1          int64
#  31    Genre_2          int64
#  32    Genre_3          int64
#  33    Genre_4          int64
#  34    Genre_5          int64
#  35    Genre_6          int64
#  36    Genre_7          int64
#  37    Genre_8          int64
#  38    Genre_9          int64
#  39    Genre_10         int64
#  40    Genre_11         int64
#  41    Genre_12         int64
#  42    Publisher_1      int64
#  43    Publisher_2      int64
#  44    Publisher_3      int64
#  45    Publisher_4      int64
#  46    Publisher_5      int64
#  47    Publisher_6      int64
#  48    Publisher_7      int64
#  49    Publisher_8      int64
#  50    Publisher_9      int64
#  51    Publisher_10     int64
#  52    Publisher_11     int64
#  53    Publisher_12     int64
#  54    Publisher_13     int64
#  55    Publisher_14     int64
#  56    Publisher_15     int64
#  57    Publisher_16     int64
#  58    Publisher_17     int64
#  59    Publisher_18     int64
#  60    Publisher_19     int64
#  61    Publisher_20     int64
#  62    Publisher_21     int64
#  63    Publisher_22     int64
#  64    Publisher_23     int64
#  65    Publisher_24     int64
#  66    Publisher_25     int64
#  67    Publisher_26     int64
#  68    Publisher_27     int64
#  69    Publisher_28     int64
#  70    Publisher_29     int64
#  71    Publisher_30     int64
#  72    Publisher_31     int64
#  73    Publisher_32     int64
#  74    Publisher_33     int64
#  75    Publisher_34     int64
#  76    Publisher_35     int64
#  77    Publisher_36     int64
#  78    Publisher_37     int64
#  79    Publisher_38     int64
#  80    Publisher_39     int64
#  81    Publisher_40     int64
#  82    Publisher_41     int64
#  83    Publisher_42     int64
#  84    Publisher_43     int64
#  85    Publisher_44     int64
#  86    Publisher_45     int64
#  87    Publisher_46     int64
#  88    Publisher_47     int64
#  89    Publisher_48     int64
#  90    Publisher_49     int64
#  91    Publisher_50     int64
#  92    Publisher_51     int64
#  93    Publisher_52     int64
#  94    Publisher_53     int64
#  95    Publisher_54     int64
#  96    Publisher_55     int64
#  97    Publisher_56     int64
#  98    Publisher_57     int64
#  99    Publisher_58     int64
#  100   Publisher_59     int64
#  101   Publisher_60     int64
#  102   Publisher_61     int64
#  103   Publisher_62     int64
#  104   Publisher_63     int64
#  105   Publisher_64     int64
#  106   Publisher_65     int64
#  107   Publisher_66     int64
#  108   Publisher_67     int64
#  109   Publisher_68     int64
#  110   Publisher_69     int64
#  111   Publisher_70     int64
#  112   Publisher_71     int64
#  113   Publisher_72     int64
#  114   Publisher_73     int64
#  115   Publisher_74     int64
#  116   Publisher_75     int64
#  117   Publisher_76     int64
#  118   Publisher_77     int64
#  119   Publisher_78     int64
#  120   Publisher_79     int64
#  121   Publisher_80     int64
#  122   Publisher_81     int64
#  123   Publisher_82     int64
#  124   Publisher_83     int64
#  125   Publisher_84     int64
#  126   Publisher_85     int64
#  127   Publisher_86     int64
#  128   Publisher_87     int64
#  129   Publisher_88     int64
#  130   Publisher_89     int64
#  131   Publisher_90     int64
#  132   Publisher_91     int64
#  133   Publisher_92     int64
#  134   Publisher_93     int64
#  135   Publisher_94     int64
#  136   Publisher_95     int64
#  137   Publisher_96     int64
#  138   Publisher_97     int64
#  139   Publisher_98     int64
#  140   Publisher_99     int64
#  141   Publisher_100    int64
#  142   Publisher_101    int64
#  143   Publisher_102    int64
#  144   Publisher_103    int64
#  145   Publisher_104    int64
#  146   Publisher_105    int64
#  147   Publisher_106    int64
#  148   Publisher_107    int64
#  149   Publisher_108    int64
#  150   Publisher_109    int64
#  151   Publisher_110    int64
#  152   Publisher_111    int64
#  153   Publisher_112    int64
#  154   Publisher_113    int64
#  155   Publisher_114    int64
#  156   Publisher_115    int64
#  157   Publisher_116    int64
#  158   Publisher_117    int64
#  159   Publisher_118    int64
#  160   Publisher_119    int64
#  161   Publisher_120    int64
#  162   Publisher_121    int64
#  163   Publisher_122    int64
#  164   Publisher_123    int64
#  165   Publisher_124    int64
#  166   Publisher_125    int64
#  167   Publisher_126    int64
#  168   Publisher_127    int64
#  169   Publisher_128    int64
#  170   Publisher_129    int64
#  171   Publisher_130    int64
#  172   Publisher_131    int64
#  173   Publisher_132    int64
#  174   Publisher_133    int64
#  175   Publisher_134    int64
#  176   Publisher_135    int64
#  177   Publisher_136    int64
#  402   Publisher_361    int64
#  403   Publisher_362    int64
#  404   Publisher_363    int64
#  405   Publisher_364    int64
#  406   Publisher_365    int64
#  407   Publisher_366    int64
#  408   Publisher_367    int64
#  409   Publisher_368    int64
#  410   Publisher_369    int64
#  411   Publisher_370    int64
#  412   Publisher_371    int64
#  413   Publisher_372    int64
#  414   Publisher_373    int64
#  415   Publisher_374    int64
#  416   Publisher_375    int64
#  417   Publisher_376    int64
#  418   Publisher_377    int64
#  419   Publisher_378    int64
#  420   Publisher_379    int64
#  421   Publisher_380    int64
#  422   Publisher_381    int64
#  423   Publisher_382    int64
#  424   Publisher_383    int64
#  425   Publisher_384    int64
#  426   Publisher_385    int64
#  427   Publisher_386    int64
#  428   Publisher_387    int64
#  429   Publisher_388    int64
#  430   Publisher_389    int64
#  431   Publisher_390    int64
#  432   Publisher_391    int64
#  433   Publisher_392    int64
#  434   Publisher_393    int64
#  435   Publisher_394    int64
#  436   Publisher_395    int64
#  437   Publisher_396    int64
#  438   Publisher_397    int64
#  439   Publisher_398    int64
#  440   Publisher_399    int64
#  441   Publisher_400    int64
#  442   Publisher_401    int64
#  443   Publisher_402    int64
#  444   Publisher_403    int64
#  445   Publisher_404    int64
#  446   Publisher_405    int64
#  447   Publisher_406    int64
#  448   Publisher_407    int64
#  449   Publisher_408    int64
#  450   Publisher_409    int64
#  451   Publisher_410    int64
#  452   Publisher_411    int64
#  453   Publisher_412    int64
#  454   Publisher_413    int64
#  455   Publisher_414    int64
#  456   Publisher_415    int64
#  457   Publisher_416    int64
#  458   Publisher_417    int64
#  459   Publisher_418    int64
#  460   Publisher_419    int64
#  461   Publisher_420    int64
#  462   Publisher_421    int64
#  463   Global_Sales     float64
#  464   developper_1     int64
#  465   developper_2     int64
#  466   developper_3     int64
#  467   developper_4     int64
#  468   developper_5     int64
#  469   developper_6     int64
#  470   developper_7     int64
#  471   developper_8     int64
#  472   developper_9     int64
#  473   developper_10    int64
#  474   developper_11    int64
#  475   developper_12    int64
#  476   developper_13    int64
#  477   developper_14    int64
#  478   developper_15    int64
#  479   developper_16    int64
#  480   developper_17    int64
#  481   developper_18    int64
#  482   developper_19    int64
#  483   developper_20    int64
#  484   developper_21    int64
#  485   developper_22    int64
#  486   developper_23    int64
#  487   developper_24    int64
#  488   developper_25    int64
#  489   developper_26    int64
#  490   developper_27    int64
#  491   developper_28    int64
#  492   developper_29    int64
#  493   developper_30    int64
#  494   developper_31    int64
#  495   developper_32    int64
#  496   developper_33    int64
#  497   developper_34    int64
#  498   developper_35    int64
#  499   developper_36    int64
#  500   developper_37    int64
#  501   developper_38    int64
#  502   developper_39    int64
#  503   developper_40    int64
#  504   developper_41    int64
#  505   developper_42    int64
#  506   developper_43    int64
#  507   developper_44    int64
#  508   developper_45    int64
#  509   developper_46    int64
#  510   developper_47    int64
#  511   developper_48    int64
#  512   developper_49    int64
#  513   developper_50    int64
#  514   developper_51    int64
#  515   developper_52    int64
#  516   developper_53    int64
#  517   developper_54    int64
#  518   developper_55    int64
#  519   developper_56    int64
#  520   developper_57    int64
#  521   developper_58    int64
#  1041  developper_578   int64
#  1042  developper_579   int64
#  1043  developper_580   int64
#  1044  developper_581   int64
#  1045  developper_582   int64
#  1046  developper_583   int64
#  1047  developper_584   int64
#  1048  developper_585   int64
#  1049  developper_586   int64
#  1050  developper_587   int64
#  1051  developper_588   int64
#  1052  developper_589   int64
#  1053  developper_590   int64
#  1054  developper_591   int64
#  1055  developper_592   int64
#  1056  developper_593   int64
#  1057  developper_594   int64
#  1058  developper_595   int64
#  1059  developper_596   int64
#  1060  developper_597   int64
#  1061  developper_598   int64
#  1062  developper_599   int64
#  1063  developper_600   int64
#  1064  developper_601   int64
#  1065  developper_602   int64
#  1066  developper_603   int64
#  1067  developper_604   int64
#  1068  developper_605   int64
#  1069  developper_606   int64
#  1070  developper_607   int64
#  1071  developper_608   int64
#  1072  developper_609   int64
#  1073  developper_610   int64
#  1074  developper_611   int64
#  1075  developper_612   int64
#  1076  developper_613   int64
#  1077  developper_614   int64
#  1078  developper_615   int64
#  1079  developper_616   int64
#  1080  developper_617   int64
#  1081  developper_618   int64
#  1082  developper_619   int64
#  1083  developper_620   int64
#  1084  developper_621   int64
#  1085  developper_622   int64
#  1086  developper_623   int64
#  1087  developper_624   int64
#  1088  developper_625   int64
#  1089  developper_626   int64
#  1090  developper_627   int64
#  1091  developper_628   int64
#  1092  developper_629   int64
#  1093  developper_630   int64
#  1094  developper_631   int64
#  1095  developper_632   int64
#  1096  developper_633   int64
#  1097  developper_634   int64
#  1098  developper_635   int64
#  1099  developper_636   int64
#  1100  developper_637   int64
#  1101  developper_638   int64
#  1102  developper_639   int64
#  1103  developper_640   int64
#  1104  developper_641   int64
#  1105  developper_642   int64
#  1106  developper_643   int64
#  1107  developper_644   int64
#  1108  developper_645   int64
#  1109  developper_646   int64
#  1110  developper_647   int64
#  1111  developper_648   int64
#  1112  developper_649   int64
#  1113  developper_650   int64
#  1114  developper_651   int64
#  1115  developper_652   int64
#  1116  developper_653   int64
#  1117  developper_654   int64
#  1118  developper_655   int64
#  1119  developper_656   int64
#  1120  developper_657   int64
#  1121  developper_658   int64
#  1122  developper_659   int64
#  1123  developper_660   int64
#  1124  developper_661   int64
#  1125  developper_662   int64
#  1126  developper_663   int64
#  1127  developper_664   int64
#  1128  developper_665   int64
#  1129  developper_666   int64
#  1130  developper_667   int64
#  1131  developper_668   int64
#  1132  developper_669   int64
#  1133  developper_670   int64
#  1134  developper_671   int64
#  1135  developper_672   int64
#  1136  developper_673   int64
#  1137  developper_674   int64
#  1138  developper_675   int64
#  1139  developper_676   int64
#  1140  developper_677   int64
#  1141  developper_678   int64
#  1142  developper_679   int64
#  1143  developper_680   int64
#  1144  developper_681   int64
#  1145  developper_682   int64
#  1146  developper_683   int64
#  1147  developper_684   int64
#  1148  developper_685   int64
#  1149  developper_686   int64
#  1150  developper_687   int64
#  1151  developper_688   int64
#  1152  developper_689   int64
#  1153  developper_690   int64
#  1154  developper_691   int64
#  1155  developper_692   int64
#  1156  developper_693   int64
#  1157  developper_694   int64
#  1158  developper_695   int64
#  1159  developper_696   int64
#  1160  developper_697   int64
#  1161  developper_698   int64
#  1162  developper_699   int64
#  1163  developper_700   int64
#  1164  developper_701   int64
#  1165  developper_702   int64
#  1166  developper_703   int64
#  1167  developper_704   int64
#  1168  developper_705   int64
#  1169  developper_706   int64
#  1170  developper_707   int64
#  1171  developper_708   int64
#  1172  developper_709   int64
#  1173  developper_710   int64
#  1174  developper_711   int64
#  1175  developper_712   int64
#  1176  developper_713   int64
#  1177  developper_714   int64
#  1178  developper_715   int64
#  1179  developper_716   int64
#  1180  developper_717   int64
#  1181  developper_718   int64
#  1182  developper_719   int64
#  1183  developper_720   int64
#  1184  developper_721   int64
#  1185  developper_722   int64
#  1186  developper_723   int64
#  1187  developper_724   int64
#  1188  developper_725   int64
#  1189  developper_726   int64
#  1190  developper_727   int64
#  1191  developper_728   int64
#  1192  developper_729   int64
#  1193  developper_730   int64
#  1194  developper_731   int64
#  1195  developper_732   int64
#  1196  developper_733   int64
#  1197  developper_734   int64
#  1198  developper_735   int64
#  1199  developper_736   int64
#  1200  developper_737   int64
#  1201  developper_738   int64
#  1202  developper_739   int64
#  1203  developper_740   int64
#  1204  developper_741   int64
#  1205  developper_742   int64
#  1206  developper_743   int64
#  1207  developper_744   int64
#  1208  developper_745   int64
#  1209  developper_746   int64
#  1210  developper_747   int64
#  1211  developper_748   int64
#  1212  developper_749   int64
#  1213  developper_750   int64
#  1214  developper_751   int64
#  1215  developper_752   int64
#  1216  developper_753   int64
#  1217  developper_754   int64
#  1218  developper_755   int64
#  1219  developper_756   int64
#  1220  developper_757   int64
#  1221  developper_758   int64
#  1222  developper_759   int64
#  1223  developper_760   int64
#  1224  developper_761   int64
#  1225  developper_762   int64
#  1226  developper_763   int64
#  1227  developper_764   int64
#  1228  developper_765   int64
#  1229  developper_766   int64
#  1230  developper_767   int64
#  1231  developper_768   int64
#  1232  developper_769   int64
#  1233  developper_770   int64
#  1234  developper_771   int64
#  1235  developper_772   int64
#  1236  developper_773   int64
#  1237  developper_774   int64
#  1238  developper_775   int64
#  1239  developper_776   int64
#  1240  developper_777   int64
#  1241  developper_778   int64
#  1242  developper_779   int64
#  1243  developper_780   int64
#  1244  developper_781   int64
#  1245  developper_782   int64
#  1246  developper_783   int64
#  1247  developper_784   int64
#  1248  developper_785   int64
#  1249  developper_786   int64
#  1250  developper_787   int64
#  1251  developper_788   int64
#  1252  developper_789   int64
#  1253  developper_790   int64
#  1254  developper_791   int64
#  1255  developper_792   int64
#  1256  developper_793   int64
#  1257  developper_794   int64
#  1258  developper_795   int64
#  1259  developper_796   int64
#  1260  developper_797   int64
#  1261  developper_798   int64
#  1262  developper_799   int64
#  1263  developper_800   int64
#  1264  developper_801   int64
#  1265  developper_802   int64
#  1266  developper_803   int64
#  1267  developper_804   int64
#  1268  developper_805   int64
#  1269  developper_806   int64
#  1270  developper_807   int64
#  1271  developper_808   int64
#  1272  developper_809   int64
#  1273  developper_810   int64
#  1274  developper_811   int64
#  1275  developper_812   int64
#  1276  developper_813   int64
#  1277  developper_814   int64
#  1278  developper_815   int64
#  1279  developper_816   int64
#  1280  developper_817   int64
#  1281  developper_818   int64
#  1282  developper_819   int64
#  1283  developper_820   int64
#  1284  developper_821   int64
#  1285  developper_822   int64
#  1286  developper_823   int64
#  1287  developper_824   int64
#  1288  developper_825   int64
#  1289  developper_826   int64
#  1290  developper_827   int64
#  1291  developper_828   int64
#  1292  developper_829   int64
#  1293  developper_830   int64
#  1294  developper_831   int64
#  1295  developper_832   int64
#  1296  developper_833   int64
#  1297  developper_834   int64
#  1298  developper_835   int64
#  1299  developper_836   int64
#  1300  developper_837   int64
#  1301  developper_838   int64
#  1302  developper_839   int64
#  1303  developper_840   int64
#  1304  developper_841   int64
#  1305  developper_842   int64
#  1306  developper_843   int64
#  1307  developper_844   int64
#  1308  developper_845   int64
#  1309  developper_846   int64
#  1310  developper_847   int64
#  1311  developper_848   int64
#  1312  developper_849   int64
#  1313  developper_850   int64
#  1314  developper_851   int64
#  1315  developper_852   int64
#  1316  developper_853   int64
#  1317  developper_854   int64
#  1318  developper_855   int64
#  1319  developper_856   int64
#  1320  developper_857   int64
#  1321  developper_858   int64
#  1322  developper_859   int64
#  1323  developper_860   int64
#  1324  developper_861   int64
#  1325  developper_862   int64
#  1326  developper_863   int64
#  1327  developper_864   int64
#  1328  developper_865   int64
#  1329  developper_866   int64
#  1330  developper_867   int64
#  1331  developper_868   int64
#  1332  developper_869   int64
#  1333  developper_870   int64
#  1334  developper_871   int64
#  1335  developper_872   int64
#  1336  developper_873   int64
#  1337  developper_874   int64
#  1338  developper_875   int64
#  1339  developper_876   int64
#  1340  developper_877   int64
#  1341  developper_878   int64
#  1342  developper_879   int64
#  1343  developper_880   int64
#  1344  developper_881   int64
#  1345  developper_882   int64
#  1346  developper_883   int64
#  1347  developper_884   int64
#  1348  developper_885   int64
#  1349  developper_886   int64
#  1350  developper_887   int64
#  1351  developper_888   int64
#  1352  developper_889   int64
#  1353  developper_890   int64
#  1354  developper_891   int64
#  1355  developper_892   int64
#  1356  developper_893   int64
#  1357  developper_894   int64
#  1358  developper_895   int64
#  1359  developper_896   int64
#  1360  developper_897   int64
#  1361  developper_898   int64
#  1362  developper_899   int64
#  1363  developper_900   int64
#  1364  developper_901   int64
#  1365  developper_902   int64
#  1366  developper_903   int64
#  1367  developper_904   int64
#  1368  developper_905   int64
#  1369  developper_906   int64
#  1370  developper_907   int64
#  1371  developper_908   int64
#  1372  developper_909   int64
#  1373  developper_910   int64
#  1374  developper_911   int64
#  1375  developper_912   int64
#  1376  developper_913   int64
#  1377  developper_914   int64
#  1378  developper_915   int64
#  1379  developper_916   int64
#  1380  developper_917   int64
#  1381  developper_918   int64
#  1382  developper_919   int64
#  1383  developper_920   int64
#  1384  developper_921   int64
#  1385  developper_922   int64
#  1386  developper_923   int64
#  1387  developper_924   int64
#  1388  developper_925   int64
#  1389  developper_926   int64
#  1390  developper_927   int64
#  1391  developper_928   int64
#  1392  developper_929   int64
#  1393  developper_930   int64
#  1394  developper_931   int64
#  1395  developper_932   int64
#  1396  developper_933   int64
#  1397  developper_934   int64
#  1398  developper_935   int64
#  1399  developper_936   int64
#  1400  developper_937   int64
#  1401  developper_938   int64
#  1402  developper_939   int64
#  1403  developper_940   int64
#  1404  developper_941   int64
#  1405  developper_942   int64
#  1406  developper_943   int64
#  1407  developper_944   int64
#  1408  developper_945   int64
#  1409  developper_946   int64
#  1410  developper_947   int64
#  1411  developper_948   int64
#  1412  developper_949   int64
#  1413  developper_950   int64
#  1414  developper_951   int64
#  1415  developper_952   int64
#  1416  developper_953   int64
#  1417  developper_954   int64
#  1418  developper_955   int64
#  1419  developper_956   int64
#  1420  developper_957   int64
#  1421  developper_958   int64
#  1422  developper_959   int64
#  1423  developper_960   int64
#  1424  developper_961   int64
#  1425  developper_962   int64
#  1426  developper_963   int64
#  1427  developper_964   int64
#  1428  developper_965   int64
#  1429  developper_966   int64
#  1430  developper_967   int64
#  1431  developper_968   int64
#  1432  developper_969   int64
#  1433  developper_970   int64
#  1434  developper_971   int64
#  1435  developper_972   int64
#  1436  developper_973   int64
#  1437  developper_974   int64
#  1438  developper_975   int64
#  1439  developper_976   int64
#  1440  developper_977   int64
#  1441  developper_978   int64
#  1442  developper_979   int64
#  1443  developper_980   int64
#  1444  developper_981   int64
#  1445  developper_982   int64
#  1446  developper_983   int64
#  1447  developper_984   int64
#  1448  developper_985   int64
#  1449  developper_986   int64
#  1450  developper_987   int64
#  1451  developper_988   int64
#  1452  developper_989   int64
#  1453  developper_990   int64
#  1454  developper_991   int64
#  1455  developper_992   int64
#  1456  developper_993   int64
#  1457  developper_994   int64
#  1458  developper_995   int64
#  1459  developper_996   int64
#  1460  developper_997   int64
#  1461  developper_998   int64
#  1462  developper_999   int64
#  1463  developper_1000  int64
#  1464  developper_1001  int64
#  1465  developper_1002  int64
#  1466  developper_1003  int64
#  1467  developper_1004  int64
#  1468  developper_1005  int64
#  1469  developper_1006  int64
#  1470  developper_1007  int64
#  1471  developper_1008  int64
#  1472  developper_1009  int64
#  1473  developper_1010  int64
#  1474  developper_1011  int64
#  1475  developper_1012  int64
#  1476  developper_1013  int64
#  1477  developper_1014  int64
#  1478  developper_1015  int64
#  1479  developper_1016  int64
#  1480  developper_1017  int64
#  1481  developper_1018  int64
#  1482  developper_1019  int64
#  1483  developper_1020  int64
#  1484  developper_1021  int64
#  1485  developper_1022  int64
#  1486  developper_1023  int64
#  1487  developper_1024  int64
#  1488  developper_1025  int64
#  1489  developper_1026  int64
#  1490  developper_1027  int64
#  1491  developper_1028  int64
#  1492  developper_1029  int64
#  1493  developper_1030  int64
# ...
#  1743  developper_1280  int64
#  1744  developper_1281  int64
#  1745  developper_1282  int64
#  1746  developper_1283  int64
#  1747  developper_1284  int64
#  1748  developper_1285  int64
#  1749  developper_1286  int64
#  1750  developper_1287  int64
#  1751  developper_1288  int64
#  1752  developper_1289  int64
#  1753  developper_1290  int64
#  1754  developper_1291  int64
#  1755  developper_1292  int64
#  1756  developper_1293  int64
#  1757  developper_1294  int64
#  1758  developper_1295  int64
#  1759  developper_1296  int64
#  1760  developper_1297  int64
#  1761  developper_1298  int64
#  1762  developper_1299  int64
#  1763  developper_1300  int64
#  1764  developper_1301  int64
#  1765  developper_1302  int64
#  1766  developper_1303  int64
#  1767  developper_1304  int64
#  1768  developper_1305  int64
#  1769  developper_1306  int64
#  1770  developper_1307  int64
#  1771  developper_1308  int64
#  1772  developper_1309  int64
#  1773  developper_1310  int64
#  1774  developper_1311  int64
#  1775  developper_1312  int64
#  1776  developper_1313  int64
#  1777  developper_1314  int64
#  1778  developper_1315  int64
#  1779  developper_1316  int64
#  1780  developper_1317  int64
#  1781  developper_1318  int64
#  1782  developper_1319  int64
#  1783  developper_1320  int64
#  1784  developper_1321  int64
#  1785  developper_1322  int64
#  1786  developper_1323  int64
#  1787  developper_1324  int64
#  1788  developper_1325  int64
#  1789  developper_1326  int64
#  1790  developper_1327  int64
#  1791  developper_1328  int64
#  1792  developper_1329  int64
#  1793  developper_1330  int64
#  1794  developper_1331  int64
#  1795  developper_1332  int64
#  1796  developper_1333  int64
#  1797  developper_1334  int64
#  1798  developper_1335  int64
#  1799  developper_1336  int64
#  1800  developper_1337  int64
#  1801  developper_1338  int64
#  1802  developper_1339  int64
#  1803  developper_1340  int64
#  1804  developper_1341  int64
#  1805  developper_1342  int64
#  1806  developper_1343  int64
#  1807  developper_1344  int64
#  1808  developper_1345  int64
#  1809  developper_1346  int64
#  1810  developper_1347  int64
#  1811  developper_1348  int64
#  1812  developper_1349  int64
#  1813  developper_1350  int64
#  1814  developper_1351  int64
#  1815  developper_1352  int64
#  1816  developper_1353  int64
#  1817  developper_1354  int64
#  1818  developper_1355  int64
#  1819  developper_1356  int64
#  1820  developper_1357  int64
#  1821  developper_1358  int64
#  1822  developper_1359  int64
#  1823  developper_1360  int64
#  1824  developper_1361  int64
#  1825  developper_1362  int64
#  1826  developper_1363  int64
#  1827  developper_1364  int64
#  1828  developper_1365  int64
#  1829  developper_1366  int64
#  1830  developper_1367  int64
#  1831  developper_1368  int64
#  1832  developper_1369  int64
#  1833  developper_1370  int64
#  1834  developper_1371  int64
#  1835  developper_1372  int64
#  1836  developper_1373  int64
#  1837  developper_1374  int64
#  1838  developper_1375  int64
#  1839  developper_1376  int64
#  1840  developper_1377  int64
#  1841  developper_1378  int64
#  1842  developper_1379  int64
#  1843  developper_1380  int64
#  1844  developper_1381  int64
#  1845  developper_1382  int64
#  1846  developper_1383  int64
#  1847  developper_1384  int64
#  1848  developper_1385  int64
#  1849  developper_1386  int64
#  1850  developper_1387  int64
#  1851  developper_1388  int64
#  1852  developper_1389  int64
#  1853  developper_1390  int64
#  1854  developper_1391  int64
#  1855  developper_1392  int64
#  1856  developper_1393  int64
#  1857  developper_1394  int64
#  1858  developper_1395  int64
#  1859  developper_1396  int64
#  1860  developper_1397  int64
#  1861  developper_1398  int64
#  1862  developper_1399  int64
#  1863  developper_1400  int64
#  1864  developper_1401  int64
#  1865  developper_1402  int64
#  1866  developper_1403  int64
#  1867  developper_1404  int64
#  1868  developper_1405  int64
#  1869  developper_1406  int64
#  1870  developper_1407  int64
#  1871  developper_1408  int64
#  1872  developper_1409  int64
#  1873  developper_1410  int64
#  1874  developper_1411  int64
#  1875  developper_1412  int64
#  1876  developper_1413  int64
#  1877  developper_1414  int64
#  1878  developper_1415  int64
#  1879  developper_1416  int64
#  1880  developper_1417  int64
#  1881  developper_1418  int64
#  1882  developper_1419  int64
#  1883  developper_1420  int64
#  1884  developper_1421  int64
#  1885  developper_1422  int64
#  1886  developper_1423  int64
#  1887  developper_1424  int64
#  1888  developper_1425  int64
#  1889  developper_1426  int64
#  1890  developper_1427  int64
#  1891  developper_1428  int64
#  1892  developper_1429  int64
#  1893  developper_1430  int64
#  1894  developper_1431  int64
#  1895  developper_1432  int64
#  1896  developper_1433  int64
#  1897  developper_1434  int64
#  1898  developper_1435  int64
#  1899  developper_1436  int64
#  1900  developper_1437  int64
#  1901  developper_1438  int64
#  1902  developper_1439  int64
#  1903  developper_1440  int64
#  1904  developper_1441  int64
#  1905  developper_1442  int64
#  1906  developper_1443  int64
#  1907  developper_1444  int64
#  1908  developper_1445  int64
#  1909  developper_1446  int64
#  1910  developper_1447  int64
#  1911  developper_1448  int64
#  1912  developper_1449  int64
#  1913  developper_1450  int64
#  1914  developper_1451  int64
#  1915  developper_1452  int64
#  1916  developper_1453  int64
#  1917  developper_1454  int64
#  1918  developper_1455  int64
#  1919  developper_1456  int64
#  1920  developper_1457  int64
#  1921  developper_1458  int64
#  1922  developper_1459  int64
#  1923  developper_1460  int64
#  1924  developper_1461  int64
#  1925  developper_1462  int64
#  1926  developper_1463  int64
#  1927  developper_1464  int64
#  1928  developper_1465  int64
#  1929  developper_1466  int64
#  1930  developper_1467  int64
#  1931  developper_1468  int64
#  1932  developper_1469  int64
#  1933  developper_1470  int64
#  1934  developper_1471  int64
#  1935  developper_1472  int64
#  1936  developper_1473  int64
#  1937  developper_1474  int64
#  1938  developper_1475  int64
#  1939  developper_1476  int64
#  1940  developper_1477  int64
#  1941  developper_1478  int64
#  1942  developper_1479  int64
#  1943  developper_1480  int64
#  1944  developper_1481  int64
#  1945  developper_1482  int64
#  1946  developper_1483  int64
#  1947  developper_1484  int64
#  1948  developper_1485  int64
#  1949  developper_1486  int64
#  1950  developper_1487  int64
#  1951  developper_1488  int64
#  1952  developper_1489  int64
#  1953  developper_1490  int64
#  1954  developper_1491  int64
#  1955  developper_1492  int64
#  1956  developper_1493  int64
#  1957  developper_1494  int64
#  1958  developper_1495  int64
#  1959  developper_1496  int64
#  1960  developper_1497  int64
#  1961  developper_1498  int64
#  1962  developper_1499  int64
#  1963  developper_1500  int64
#  1964  developper_1501  int64
#  1965  developper_1502  int64
#  1966  developper_1503  int64
#  1967  developper_1504  int64
#  1968  developper_1505  int64
#  1969  developper_1506  int64
#  1970  developper_1507  int64
#  1971  developper_1508  int64
#  1972  developper_1509  int64
#  1973  developper_1510  int64
#  1974  developper_1511  int64
#  1975  developper_1512  int64
#  1976  developper_1513  int64
#  1977  developper_1514  int64
#  1978  developper_1515  int64
#  1979  developper_1516  int64
#  1980  developper_1517  int64
#  1981  developper_1518  int64
#  1982  developper_1519  int64
#  1983  developper_1520  int64
#  1984  developper_1521  int64
#  1985  developper_1522  int64
#  1986  developper_1523  int64
#  1987  developper_1524  int64
#  1988  developper_1525  int64
#  1989  developper_1526  int64
#  1990  developper_1527  int64
#  2215  developper_1752  int64
#  2216  developper_1753  int64
#  2217  developper_1754  int64
#  2218  developper_1755  int64
#  2219  developper_1756  int64
#  2220  developper_1757  int64
#  2221  developper_1758  int64
#  2222  developper_1759  int64
#  2223  developper_1760  int64
#  2224  developper_1761  int64
#  2225  developper_1762  int64
#  2226  developper_1763  int64
#  2227  developper_1764  int64
#  2228  developper_1765  int64
#  2229  developper_1766  int64
#  2230  developper_1767  int64
#  2231  developper_1768  int64
#  2232  developper_1769  int64
#  2233  developper_1770  int64
#  2234  developper_1771  int64
#  2235  developper_1772  int64
#  2236  metaNote         float64
#  2237  metaNbVote       float64
#  2238  userNote         float64
#  2239  userNbVote       float64
#  2240  serieB           int64
# dtypes: float64(6), int64(2235)
# memory usage: 197.1 MB

# %% [markdown]
# # Preprocessing

# %%
#scaler = preprocessing.RobustScaler().fit_transform(df2)

# définition de la target et data
target = np.log(df2['Global_Sales'])
data = df2.drop(['Global_Sales'],axis=1)

# séparation en jeu d'entrainement et de test
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.2)

# Avec outliers
scaler = preprocessing.RobustScaler()

#Sans outliers
#scaler = preprocessing.StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# # Régression Linéaire

# %%
# Test du modèle de Régression Linéaire

# Brut

print("Données brutes")

lr = LinearRegression()
lr.fit(X_train, y_train)

print("Train score :", lr.score(X_train,y_train))
print("Test score :",lr.score(X_test,y_test))

y_pred = lr.predict(X_test)
print("MAE : ",mean_absolute_error(y_test, y_pred))

print("\n")

# Scaled

print("Données Scalées")

lr_scaled = LinearRegression()
lr_scaled.fit(X_train_scaled, y_train)

print("Train score :", lr_scaled.score(X_train_scaled,y_train))
print("Test score :",lr_scaled.score(X_test_scaled,y_test))

y_pred = lr_scaled.predict(X_test_scaled)
print("MAE : ",mean_absolute_error(y_test, y_pred))
# Out:
# Données brutes
# Train score : 0.4724730674537798
# Test score : -834796695504.8677
# MAE :  120728.90391241288
#
#
# Données Scalées
# Train score : 0.47246833508297104
# Test score : -1.0361123079000008e+17
# MAE :  11394969.309990924

# %% [markdown]
# # Modèle Ridge

# %%
# Test du modèle Ridge
RD_model = Ridge()

tuned_parameters = {'alpha': list(x / 10 for x in range(1, 101)),
                    'fit_intercept': [True,False], 
                    'normalize' :[False, True],
                    'solver': ['auto', 'cholesky', 'lsqr', 'sparse_cg', 'lbfgs']}

RD = GridSearchCV(RD_model, tuned_parameters, cv = 10)
RD.fit(X_train, y_train)

print("Train score :", RD.score(X_train,y_train))
print("Test score :",RD.score(X_test,y_test))

y_pred = RD.predict(X_test)
print("MAE : ",mean_absolute_error(y_test, y_pred))

print ("Best Params", RD.best_params_)
print ("Best Score", RD.best_score_)
# Out:
# Train score : 0.46167950101220345
# Test score : 0.44645481136559584
# MAE :  0.8408132800439054
# Best Params {'alpha': 3.1, 'fit_intercept': True, 'normalize': False, 'solver': 'auto'}
# Best Score 0.4282221097914462

# %%
# Test sur données scalées

RD_model = Ridge()

tuned_parameters = {'alpha': list(x / 10 for x in range(1, 101)),
                    'fit_intercept': [True,False], 
                    'normalize' :[False, True],
                    'solver': ['auto', 'cholesky', 'lsqr', 'sparse_cg', 'lbfgs']}

RD_scaled = GridSearchCV(RD_model, tuned_parameters, cv = 10)
RD_scaled.fit(X_train_scaled, y_train)

print("Train score :", RD_scaled.score(X_train_scaled,y_train))
print("Test score :",RD_scaled.score(X_test_scaled,y_test))

y_pred = RD_scaled.predict(X_test_scaled)
print("MAE : ",mean_absolute_error(y_test, y_pred))

print ("Best Params", RD_scaled.best_params_)
print ("Best Score", RD_scaled.best_score_)
# Out:
# Train score : 0.4614301594943573
# Test score : 0.44640692689021755
# MAE :  0.8408634291036895
# Best Params {'alpha': 3.2, 'fit_intercept': True, 'normalize': False, 'solver': 'auto'}
# Best Score 0.42822289969775823

# %% [markdown]
# # Modèle Lasso

# %%
# Test du modèle Lasso sur données brutes

LS_model = Lasso()

tuned_parameters = {'alpha': list(x / 10 for x in range(1, 101)),
                    'fit_intercept': [True,False], 
                    'normalize' :[False, True],
                    'selection': ['cyclic', 'random']}

LS = GridSearchCV(LS_model, tuned_parameters, cv = 10)
LS.fit(X_train, y_train)

print("Train score :", LS.score(X_train,y_train))
print("Test score :",LS.score(X_test,y_test))

y_pred = LS.predict(X_test)
print("MAE : ",mean_absolute_error(y_test, y_pred))

print ("Best Params", LS.best_params_)
print ("Best Score", LS.best_score_)
# Out:
# Train score : 0.1585516205521531
# Test score : 0.18456699794842524
# MAE :  1.0411032604152244
# Best Params {'alpha': 0.1, 'fit_intercept': True, 'normalize': False, 'selection': 'cyclic'}
# Best Score 0.15514292926154757

# %%
# Test du modèle Lasso sur les données scalées

LS_model = Lasso()

tuned_parameters = {'alpha': list(x / 10 for x in range(1, 101)),
                    'fit_intercept': [True,False], 
                    'normalize' :[False, True],
                    'selection': ['cyclic', 'random']}


LS = GridSearchCV(LS_model, tuned_parameters, cv = 10)
LS.fit(X_train_scaled, y_train)

print("Train score :", LS.score(X_train_scaled,y_train))
print("Test score :",LS.score(X_test_scaled,y_test))

y_pred = LS.predict(X_test_scaled)
print("MAE : ",mean_absolute_error(y_test, y_pred))

print ("Best Params", LS.best_params_)
print ("Best Score", LS.best_score_)
# Out:
# Train score : 0.13521254416324713
# Test score : 0.15425242229097547
# MAE :  1.0679794363974449
# Best Params {'alpha': 0.1, 'fit_intercept': True, 'normalize': False, 'selection': 'cyclic'}
# Best Score 0.1303727590337606

# %% [markdown]
# # Modèle ElasticNet

# %%
# Test du modèle ElasticNet sur données brutes

EN_model = ElasticNet()

tuned_parameters = {'alpha': list(x / 10 for x in range(1, 101)),
                    'fit_intercept': [True,False], 
                    'normalize' :[False, True],
                    'selection': ['cyclic', 'random']}

EN = GridSearchCV(EN_model, tuned_parameters, cv = 10)
EN.fit(X_train, y_train)

print("Train score :", EN.score(X_train,y_train))
print("Test score :",EN.score(X_test,y_test))

y_pred = EN.predict(X_test)
print("MAE : ",mean_absolute_error(y_test, y_pred))

print ("Best Params", EN.best_params_)
print ("Best Score", EN.best_score_)
# Out:
# Train score : 0.20072005892838118
# Test score : 0.22479524402153983
# MAE :  1.0172760816834596
# Best Params {'alpha': 0.1, 'fit_intercept': True, 'normalize': False, 'selection': 'random'}
# Best Score 0.19614580804135873

# %%
# Test du modèle ElasticNet sur données scalées

EN_model = ElasticNet()

tuned_parameters = {'alpha': list(x / 10 for x in range(1, 101)),
                    'fit_intercept': [True,False], 
                    'normalize' :[False, True],
                    'selection': ['cyclic', 'random']}

EN_scaled = GridSearchCV(EN_model, tuned_parameters, cv = 10)
EN_scaled.fit(X_train_scaled, y_train)

print("Train score :", EN_scaled.score(X_train_scaled,y_train))
print("Test score :",EN_scaled.score(X_test_scaled,y_test))

y_pred = EN_scaled.predict(X_test_scaled)
print("MAE : ",mean_absolute_error(y_test, y_pred))

print ("Best Params", EN_scaled.best_params_)
print ("Best Score", EN_scaled.best_score_)
# Out:
# Train score : 0.192155395696605
# Test score : 0.21193727843619703
# MAE :  1.028840610280023
# Best Params {'alpha': 0.1, 'fit_intercept': True, 'normalize': False, 'selection': 'random'}
# Best Score 0.1866842415225521

# %% [markdown]
# # Preprocessing pour modèles catégorielles

# %%
df3=df
df3[["Genre","Publisher", "Platform"]] = ohe.fit_transform(df[["Genre","Publisher","Platform"]])
target = (df3['Global_Sales']*100).astype('int')
data = df3.drop(['Global_Sales'],axis=1)

# séparation en jeu d'entrainement et de test
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.2)

# Scale
scaler = preprocessing.StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# # Test de différents modèles catégorielles

# %%
# Test modèle KNN

knn = KNeighborsClassifier(n_neighbors=3, metric='minkowski')
knn.fit(X_train_scaled,y_train)
print("Train score :", knn.score(X_train_scaled,y_train))
print("Test score :",knn.score(X_test_scaled,y_test))

y_pred = knn.predict(X_test)
print("MAE : ",mean_absolute_error(y_test, y_pred))
# Out:
# Train score : 0.3654679376083189
# Test score : 0.0415944540727903
# MAE :  73.84012131715771

# %%
# Test modèle Regression Logistic

print("Données brutes")
lr = LogisticRegression(C=1.0)
lr.fit(X_train_scaled,y_train)
print("Train score :", lr.score(X_train_scaled,y_train))
print("Test score :",lr.score(X_test_scaled,y_test))

y_pred = lr.predict(X_test_scaled)
print("MAE : ",mean_absolute_error(y_test, y_pred))

print("\n")
print("Données scalées")

lr = LogisticRegression(C=1.0)
lr.fit(X_train_scaled,y_train)
print("Train score :", lr.score(X_train_scaled,y_train))
print("Test score :",lr.score(X_test_scaled,y_test))

y_pred = lr.predict(X_test_scaled)
print("MAE : ",mean_absolute_error(y_test, y_pred))
# Out:
# Train score : 0.05675909878682842
# Test score : 0.04852686308492201
# MAE :  53.396447140381284
#
#
# Données scalées
# Train score : 0.05675909878682842
# Test score : 0.04852686308492201
# MAE :  53.396447140381284

# %%
# test modèle Decision Tree

#Données brutes
print("Données brutes")
dt_clf = DecisionTreeClassifier()
dt_clf.fit(X_train,y_train)
print("Train score :", dt_clf.score(X_train,y_train))
print("Test score :",dt_clf.score(X_test,y_test))

y_pred = dt_clf.predict(X_test)
print("MAE : ",mean_absolute_error(y_test, y_pred))

print("\n")
print("Données scalées")
dt_clf = DecisionTreeClassifier()
dt_clf.fit(X_train_scaled,y_train)
print("Train score :", dt_clf.score(X_train_scaled,y_train))
print("Test score :",dt_clf.score(X_test_scaled,y_test))

y_pred = dt_clf.predict(X_test_scaled)
print("MAE : ",mean_absolute_error(y_test, y_pred))
# Out:
# Données brutes
# Train score : 0.985051993067591
# Test score : 0.042027729636048526
# MAE :  56.75346620450607
#
#
# Données brutes
# Train score : 0.985051993067591
# Test score : 0.04289428076256499
# MAE :  57.4263431542461

# %%
# test modèle random forest

from sklearn.ensemble import RandomForestClassifier

print("Données brutes")
RF_clf = RandomForestClassifier()
RF_clf.fit(X_train_scaled,y_train)
print("Train score :", dt_clf.score(X_train_scaled,y_train))
print("Test score :",dt_clf.score(X_test_scaled,y_test))

y_pred = RF_clf.predict(X_test)
print("MAE : ",mean_absolute_error(y_test, y_pred))

print("\n")
print("Données scalées")

RF_clf = RandomForestClassifier()
RF_clf.fit(X_train_scaled,y_train)
print("Train score :", dt_clf.score(X_train_scaled,y_train))
print("Test score :",dt_clf.score(X_test_scaled,y_test))

y_pred = RF_clf.predict(X_test_scaled)
print("MAE : ",mean_absolute_error(y_test, y_pred))
# Out:
# Données brutes
# Train score : 0.985051993067591
# Test score : 0.04289428076256499
# MAE :  60.57538994800693
#
#
# Données scalées
# Train score : 0.985051993067591
# Test score : 0.04289428076256499
# MAE :  55.25389948006932

# %% [markdown]
# # Application du meilleur modèle

# %%
RD_final = Ridge(alpha=3.2,fit_intercept=True,normalize=False,solver="auto")

RD_final.fit(X_train_scaled, y_train)

print("Train score :", RD_final.score(X_train_scaled,y_train))
print("Test score :",RD_final.score(X_test_scaled,y_test))

y_pred = RD_final.predict(X_test_scaled)
print("MAE : ",mean_absolute_error(y_test, y_pred))
# Out:
# Train score : 0.45988888925757054
# Test score : 0.45404984122258674
# MAE :  0.8343346339751921

# %%
plt.scatter(y_test,y_pred);
plt.plot(y_test,y_test,color='red');
#plt.xlim([0,4])
#plt.ylim([0,5])

# %%
dfresult = pd.DataFrame(y_test)
dfresult['pred']=y_pred
sns.relplot(x='Global_Sales', y='pred', data=dfresult);
sns.lineplot(x='Global_Sales', y='Global_Sales', data=dfresult,color="red");
