# %%
# Importation des packaques
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re

# %%
# Importation du fichier de scraping
df = pd.read_csv('vgsales_scraping.csv')
#print(df.isnull().sum())

# Scraping Metascore
# On recherche les nombres dans Metascore correspond respectivement à la note et au nombre de vote
r = re.compile(r"[0-9]+")

# On crée les 2 conteneurs qui vont recueillir ces infos
metascorewrap_note = []
metascorewrap_nbvote = []
count = 0

for i in df['metascorewrap']:
    metascorewrap = r.findall(i)
    if len(metascorewrap)>1 :
        #print(count," : ",metascorewrap)
        #print(type(metascorewrap_note))
        metascorewrap_note.append(metascorewrap[0])
        metascorewrap_nbvote.append(metascorewrap[1])
    else :
        metascorewrap_note.append(np.nan)
        metascorewrap_nbvote.append(np.nan)
    count+=1
    
# On recherche les floats dans Userscore correspond respectivement à la note et au nombre de vote
r = re.compile(r"[0-9]+\.?[0-9]+")

# On crée les 2 conteneurs qui vont recueillir ces infos
userscorewrap_note = []
userscorewrap_nbvote = []
count = 0
df['metaNote']=metascorewrap_note
df['metaNbVote']=metascorewrap_nbvote

for i in df['userscorewrap']:
    userscorewrap = r.findall(i)
    if len(userscorewrap)>1 :
        #print(count," : ",userscorewrap)
        #print(type(metascorewrap_note))
        userscorewrap_note.append(userscorewrap[0])
        userscorewrap_nbvote.append(userscorewrap[1])
    else :
        userscorewrap_note.append(np.nan)
        userscorewrap_nbvote.append(np.nan)
    count+=1
df['userNote']=userscorewrap_note
df['userNbVote']=userscorewrap_nbvote
    
# Comparatif entre le nom du dataset et le nom sur Metacritic
samename = []
for i,j in zip(df['Name'],df['gamename']):
    if (i in j) or (j in i) : # Je fais le test dans les 2 sens, voir index 16595
        samename.append(1)
    else :
        samename.append(0)
df['samename']=samename

df['metaNote']=df['metaNote'].astype(float)
df['metaNbVote']=df['metaNbVote'].astype(float)
df['userNote']=df['userNote'].astype(float)
df['userNbVote']=df['userNbVote'].astype(float)

# %%
#print(df['metascorewrap'][52])
#print(df['userscorewrap'][0])

df=df.drop(['metascorewrap','developper','userscorewrap','nbvotes','description','top','nbratings','metascore','ratings'],axis=1)
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0      2006.0        Sports    Nintendo     41.49     29.02      3.77
# 1      1985.0      Platform    Nintendo     29.08      3.58      6.81
# 2      2008.0        Racing    Nintendo     15.85     12.88      3.79
# 3      2009.0        Sports    Nintendo     15.75     11.01      3.28
# 4      1996.0  Role-Playing    Nintendo     11.27      8.89     10.22
# ...       ...           ...         ...       ...       ...       ...
# 16593  2002.0      Platform       Kemco      0.01      0.00      0.00
# 16594  2003.0       Shooter  Infogrames      0.01      0.00      0.00
# 16595  2008.0        Racing  Activision      0.00      0.00      0.00
# 16596  2010.0        Puzzle    7G//AMES      0.00      0.01      0.00
# 16597  2003.0      Platform     Wanadoo      0.01      0.00      0.00
#
#        Other_Sales  Global_Sales                                  gamename  \
# 0             8.46         82.74                                Wii Sports
# 1             0.77         40.24     Classic NES Series: Super Mario Bros.
# 2             3.31         35.82                            Mario Kart Wii
# 3             2.96         33.00                         Wii Sports Resort
# 4             1.00         31.37  Pokemon Mystery Dungeon: Red Rescue Team
# ...            ...           ...                                       ...
# 16593         0.00          0.01                                 not found
# 16594         0.00          0.01             Men in Black II: Alien Escape
# 16595         0.00          0.01             SCORE International Baja 1000
# 16596         0.00          0.01                                 not found
# 16597         0.00          0.01                          Spirits & Spells
#
#       metaNote metaNbVote userNote userNbVote  samename
# 0           76         51      8.1        453         1
# 1           84         14      8.5         98         1
# 2           82         73      8.4       1047         1
# 3           80         73      8.2        293         1
# 4           67         17      8.3        159         0
# ...        ...        ...      ...        ...       ...
# 16593      NaN        NaN      NaN        NaN         0
# 16594       50         19      NaN        NaN         1
# 16595       29          4      NaN        NaN         1
# 16596      NaN        NaN      NaN        NaN         0
# 16597       50         10      NaN        NaN         1
#
# [16598 rows x 17 columns]

# %%
# Calcul du nombre de bons jeux (même nom) trouvés
print(df['samename'].value_counts())
print("length :",len(df))

# Suppression des mauvais jeux (pas le même nom)
df.drop(df.loc[df['samename']==0].index, inplace=True)
df
# Out:
# 1    11540
# 0     5058
# Name: samename, dtype: int64
# length : 16598
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 5          6                                            Tetris       GB
# ...      ...                                               ...      ...
# 16591  16594                               Myst IV: Revelation       PC
# 16592  16595                                          Plushees       DS
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year       Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0      2006.0      Sports    Nintendo     41.49     29.02      3.77
# 1      1985.0    Platform    Nintendo     29.08      3.58      6.81
# 2      2008.0      Racing    Nintendo     15.85     12.88      3.79
# 3      2009.0      Sports    Nintendo     15.75     11.01      3.28
# 5      1989.0      Puzzle    Nintendo     23.20      2.26      4.22
# ...       ...         ...         ...       ...       ...       ...
# 16591  2004.0   Adventure     Ubisoft      0.01      0.00      0.00
# 16592  2008.0  Simulation   Destineer      0.01      0.00      0.00
# 16594  2003.0     Shooter  Infogrames      0.01      0.00      0.00
# 16595  2008.0      Racing  Activision      0.00      0.00      0.00
# 16597  2003.0    Platform     Wanadoo      0.01      0.00      0.00
#
#        Other_Sales  Global_Sales                               gamename  \
# 0             8.46         82.74                             Wii Sports
# 1             0.77         40.24  Classic NES Series: Super Mario Bros.
# 2             3.31         35.82                         Mario Kart Wii
# 3             2.96         33.00                      Wii Sports Resort
# 5             0.58         30.26                              Tetris 99
# ...            ...           ...                                    ...
# 16591         0.00          0.01                    Myst IV: Revelation
# 16592         0.00          0.01                               Plushees
# 16594         0.00          0.01          Men in Black II: Alien Escape
# 16595         0.00          0.01          SCORE International Baja 1000
# 16597         0.00          0.01                       Spirits & Spells
#
#       metaNote metaNbVote userNote userNbVote  samename
# 0           76         51      8.1        453         1
# 1           84         14      8.5         98         1
# 2           82         73      8.4       1047         1
# 3           80         73      8.2        293         1
# 5           83         27      8.2        258         1
# ...        ...        ...      ...        ...       ...
# 16591       82         36      NaN        NaN         1
# 16592        1          3      NaN        NaN         1
# 16594       50         19      NaN        NaN         1
# 16595       29          4      NaN        NaN         1
# 16597       50         10      NaN        NaN         1
#
# [11540 rows x 17 columns]

# %%
# Recherche de série
serie = pd.DataFrame(df['Name'])
serie['serie']=0

for index,i in enumerate(serie['Name']):
    for y in serie['Name'] :
        if (i != y) & ((i in y) | (y in i)) :
            serie['serie'].iloc[index]=1
        elif (serie['serie'].iloc[index]!=1) :
            serie['serie'].iloc[index]=0

# Faire moyenne des ventes par série
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-75a7d51e2da1> in <module>
#       8             serie['serie'].iloc[index]=1
#       9         elif (serie['serie'].iloc[index]!=1) :
# ---> 10             serie['serie'].iloc[index]=0
#      11
#      12 # Faire moyenne des ventes par série
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     690
#     691         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 692         iloc._setitem_with_indexer(indexer, value, self.name)
#     693
#     694     def _validate_key(self, key, axis: int):
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1635             self._setitem_with_indexer_split_path(indexer, value, name)
#    1636         else:
# -> 1637             self._setitem_single_block(indexer, value, name)
#    1638
#    1639     def _setitem_with_indexer_split_path(self, indexer, value, name: str):
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _setitem_single_block(self, indexer, value, name)
#    1855
#    1856         # check for chained assignment
# -> 1857         self.obj._check_is_chained_assignment_possible()
#    1858
#    1859         # actually do the set
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _check_is_chained_assignment_possible(self)
#    3854         if self._is_view and self._is_cached:
#    3855             ref = self._get_cacher()
# -> 3856             if ref is not None and ref._is_mixed_type:
#    3857                 self._check_setitem_copy(stacklevel=4, t="referent", force=True)
#    3858             return True
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _is_mixed_type(self)
#    5566             return True
#    5567
# -> 5568         return self.dtypes.nunique() > 1
#    5569
#    5570     @final
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/base.py in nunique(self, dropna)
#    1084         """
#    1085         obj = remove_na_arraylike(self) if dropna else self
# -> 1086         return len(obj.unique())
#    1087
#    1088     @property
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in unique(self)
#    1870         Categories (3, object): ['a' < 'b' < 'c']
#    1871         """
# -> 1872         result = super().unique()
#    1873         return result
#    1874
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/base.py in unique(self)
#    1045                     result = np.asarray(result)
#    1046         else:
# -> 1047             result = unique1d(values)
#    1048
#    1049         return result
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/algorithms.py in unique(values)
#     406     table = htable(len(values))
#     407     uniques = table.unique(values)
# --> 408     uniques = _reconstruct_data(uniques, original.dtype, original)
#     409     return uniques
#     410
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/algorithms.py in _reconstruct_data(values, dtype, original)
#     206         return values
#     207
# --> 208     if is_extension_array_dtype(dtype):
#     209         cls = dtype.construct_array_type()
#     210         if isinstance(values, cls) and values.dtype == dtype:
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/dtypes/common.py in is_extension_array_dtype(arr_or_dtype)
#    1514     """
#    1515     dtype = getattr(arr_or_dtype, "dtype", arr_or_dtype)
# -> 1516     return isinstance(dtype, ExtensionDtype) or registry.find(dtype) is not None
#    1517
#    1518
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/dtypes/base.py in find(self, dtype)
#     409         self.dtypes.append(dtype)
#     410
# --> 411     def find(
#     412         self, dtype: Union[Type[ExtensionDtype], str]
#     413     ) -> Optional[Type[ExtensionDtype]]:
#
# KeyboardInterrupt:

# %%
# Remplacement des Notes par Quartile
df['metaNoteQ']=0
df.info()

for index,i in enumerate(df['metaNote']):
    #print("i :",i)
    #print("index :",index)
    if (i==0):
        df['metaNoteQ'].iloc[index]=0
    elif (i<25):
        df['metaNoteQ'].iloc[index]=1
    elif (i<50):
        df['metaNoteQ'].iloc[index]=2
    elif (i<75):
        df['metaNoteQ'].iloc[index]=3
    else:
        df['metaNoteQ'].iloc[index]=4
    #print("metaNoteQ :",df['metaNoteQ'].iloc[index])

#df['metaNoteQ'] = pd.qcut(df['metaNote'], q=5, labels=[0, 1, 2, 3, 4])

#df[df['metaNoteQ']==0]
df['metaNoteQ'].value_counts()

#df[df['metaNoteQ']==0]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 27 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           16598 non-null  int64
#  1   Name           16598 non-null  object
#  2   Platform       16598 non-null  object
#  3   Year           16327 non-null  float64
#  4   Genre          16598 non-null  object
#  5   Publisher      16540 non-null  object
#  6   NA_Sales       16598 non-null  float64
#  7   EU_Sales       16598 non-null  float64
#  8   JP_Sales       16598 non-null  float64
#  9   Other_Sales    16598 non-null  float64
#  10  Global_Sales   16598 non-null  float64
#  11  description    16598 non-null  object
#  12  top            16598 non-null  float64
#  13  nbratings      16598 non-null  object
#  14  metascore      16598 non-null  object
#  15  nbvotes        16598 non-null  object
#  16  ratings        16598 non-null  object
#  17  developper     16598 non-null  object
#  18  metascorewrap  16598 non-null  object
#  19  userscorewrap  16598 non-null  object
#  20  gamename       16598 non-null  object
#  21  metaNote       14958 non-null  float64
#  22  metaNbVote     14958 non-null  float64
#  23  userNote       9839 non-null   float64
#  24  userNbVote     9839 non-null   float64
#  25  samename       16598 non-null  int64
#  26  metaNoteQ      16598 non-null  int64
# dtypes: float64(11), int64(3), object(13)
# memory usage: 3.4+ MB
# 4    6694
# 3    5881
# 0    1765
# 1    1243
# 2    1015
# Name: metaNoteQ, dtype: int64

# %%
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0      2006.0        Sports    Nintendo     41.49     29.02      3.77
# 1      1985.0      Platform    Nintendo     29.08      3.58      6.81
# 2      2008.0        Racing    Nintendo     15.85     12.88      3.79
# 3      2009.0        Sports    Nintendo     15.75     11.01      3.28
# 4      1996.0  Role-Playing    Nintendo     11.27      8.89     10.22
# ...       ...           ...         ...       ...       ...       ...
# 16593  2002.0      Platform       Kemco      0.01      0.00      0.00
# 16594  2003.0       Shooter  Infogrames      0.01      0.00      0.00
# 16595  2008.0        Racing  Activision      0.00      0.00      0.00
# 16596  2010.0        Puzzle    7G//AMES      0.00      0.01      0.00
# 16597  2003.0      Platform     Wanadoo      0.01      0.00      0.00
#
#        Other_Sales  ...                developper  \
# 0             8.46  ...                  Nintendo
# 1             0.77  ...                  Nintendo
# 2             3.31  ...                  Nintendo
# 3             2.96  ...                  Nintendo
# 4             1.00  ...                 not found
# ...            ...  ...                       ...
# 16593         0.00  ...                 not found
# 16594         0.00  ...           Melbourne House
# 16595         0.00  ...    Left Field Productions
# 16596         0.00  ...                 not found
# 16597         0.00  ...  DreamCatcher Interactive
#
#                                            metascorewrap  \
# 0      \nMetascore\n\n76\n\n\n\n\n                   ...
# 1      \nMetascore\n\n84\n\n\n\n\n                   ...
# 2      \nMetascore\n\n82\n\n\n\n\n                   ...
# 3      \nMetascore\n\n80\n\n\n\n\n                   ...
# 4      \nMetascore\n\n67\n\n\n\n\n                   ...
# ...                                                  ...
# 16593                                          not found
# 16594  \nMetascore\n\n50\n\n\n\n\n                   ...
# 16595  \nMetascore\n\n29\n\n\n\n\n                   ...
# 16596                                          not found
# 16597  \nMetascore\n\n50\n\n\n\n\n                   ...
#
#                                            userscorewrap  \
# 0      \nUser Score\n8.1\n\nGenerally favorable revie...
# 1      \nUser Score\n8.5\n\nGenerally favorable revie...
# 2      \nUser Score\n8.4\n\nGenerally favorable revie...
# 3      \nUser Score\n8.2\n\nGenerally favorable revie...
# 4      \nUser Score\n\n8.3\n\n\nGenerally favorable r...
# ...                                                  ...
# 16593                                          not found
# 16594  \nUser Score\n7.8\n\nGenerally favorable revie...
# 16595  \nUser Score\n5.6\n\nMixed or average reviews-...
# 16596                                          not found
# 16597  \nUser Score\n6.0\n\nMixed or average reviews-...
#
#                                        gamename metaNote metaNbVote userNote  \
# 0                                    Wii Sports     76.0       51.0      8.1
# 1         Classic NES Series: Super Mario Bros.     84.0       14.0      8.5
# 2                                Mario Kart Wii     82.0       73.0      8.4
# 3                             Wii Sports Resort     80.0       73.0      8.2
# 4      Pokemon Mystery Dungeon: Red Rescue Team     67.0       17.0      8.3
# ...                                         ...      ...        ...      ...
# 16593                                 not found      NaN        NaN      NaN
# 16594             Men in Black II: Alien Escape     50.0       19.0      NaN
# 16595             SCORE International Baja 1000     29.0        4.0      NaN
# 16596                                 not found      NaN        NaN      NaN
# 16597                          Spirits & Spells     50.0       10.0      NaN
#
#       userNbVote samename metaNoteQ
# 0          453.0        1         4
# 1           98.0        1         4
# 2         1047.0        1         4
# 3          293.0        1         4
# 4          159.0        0         3
# ...          ...      ...       ...
# 16593        NaN        0         4
# 16594        NaN        1         3
# 16595        NaN        1         2
# 16596        NaN        0         4
# 16597        NaN        1         3
#
# [16598 rows x 27 columns]

# %%
df.to_csv("vgsales.csv", index = False)
